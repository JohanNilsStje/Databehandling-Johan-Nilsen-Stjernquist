# %%
import pandas as pd
df = pd.read_excel("data/Folkhalsomyndigheten_Covid19.xlsx")
df2 = pd.read_excel("data/Folkhalsomyndigheten_Covid19_Vaccine.xlsx")

df2
# Out:
#       Vecka    År          Region  Antal vaccinationer
# 0        52  2020     | Sverige |                 2478
# 1        52  2020       Stockholm                  289
# 2        52  2020         Uppsala                    9
# 3        52  2020    Södermanland                  116
# 4        52  2020    Östergötland                  214
# ...     ...   ...             ...                  ...
# 2107     42  2022       Gävleborg               726017
# 2108     42  2022  Västernorrland               632660
# 2109     42  2022        Jämtland               328655
# 2110     42  2022    Västerbotten               724409
# 2111     42  2022      Norrbotten               659824
#
# [2112 rows x 4 columns]

# %% [markdown]
# Nu när jag kollat snabbt på hur båda dataset är uppbyggda så får jag en ideé om att kolla hur antalet dödsfall är i korrelation till antal vaccinationer för att se om det finns något samband där.
